# %% [markdown]
# # EDA & FE of Algerian Forest Fire Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Suyash\Downloads\Algerian_forest_fires_dataset_UPDATE.csv",skiprows=1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df[121:130]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 121                             30     09  2012           25   78   14    1.4
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
# 125                             02     06  2012           30   73   13      4
# 126                             03     06  2012           29   80   14      2
# 127                             04     06  2012           30   64   14      0
# 128                             05     06  2012           32   60   14    0.2
# 129                             06     06  2012           35   54   11    0.1
#
#      FFMC  DMC    DC  ISI  BUI  FWI    Classes
# 121    45  1.9   7.5  0.2  2.4  0.1  not fire
# 122   NaN  NaN   NaN  NaN  NaN  NaN          NaN
# ...

# %%
df.drop([122,123],inplace=True)
df.reset_index(inplace=True)
df.drop('index',inplace=True,axis=1)

# %%
df[121:130]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 127  06    06  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 128  07    06  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 129  08    06  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
#
#      FWI    Classes
# 121  0.1  not fire
# 122  0.2  not fire
# 123  0.2  not fire
# 124  0.1  not fire
# 125    1  not fire
# 126  0.9  not fire
# 127  3.1      fire
# 128    6      fire
# 129  0.8  not fire

# %%
df.loc[:122,'Region']=0
df.loc[122:,'Region']=1

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %% [markdown]
# # Datatypes & Describe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 28.7+ KB

# %%
df.describe(include='all')
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   244   244   244         244  244  244   244   244  244  244  244  244
# unique   31     4     1          19   62   18    39   173  166  198  106  174
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
# mean    NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# std     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# min     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 25%     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 50%     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 75%     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
# max     NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %% [markdown]
# # Datacleaning

# %%
df.columns = [i.strip() for i in df.columns]
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df = df.astype(str)

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# nan                1
# not fire           1
# Name: Classes, dtype: int64

# %%
df[df['Classes']=='nan'].index
# Out:
# Int64Index([165], dtype='int64')

# %%
df.loc[165,"Classes"]='fire'

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               5
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df['Classes'] = df['Classes'].str.replace(" ","")

# %%
df['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '7.1 ', '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6',
#        '15', '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8',
#        '0.6', '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1',
#        '1.3', '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6',
#        '9.9', '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1',
#        '17.2', '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7',
#        '13.2', '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1',
#        '1', '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5', '12',
#        '6.4', '5.2', '3', '9.6', '4.7', 'fire   ', '14.1', '9.1', '13',
#        '17.3', '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5', '12.6',
#        '12.7', '21.6', '18.8', '10.5', '5.5', '14.8', '24', '26.3',
#        '12.2', '18.1', '24.5', '26.9', '31.1', '30.3', '26.1', '16',
# ...

# %%
df['FWI'] = df['FWI'].str.replace(" ","")

# %%
df['FWI'].unique()
# Out:
# array(['0.5', '0.4', '0.1', '0', '2.5', '7.2', '7.1', '0.3', '0.9', '5.6',
#        '0.2', '1.4', '2.2', '2.3', '3.8', '7.5', '8.4', '10.6', '15',
#        '13.9', '3.9', '12.9', '1.7', '4.9', '6.8', '3.2', '8', '0.6',
#        '3.4', '0.8', '3.6', '6', '10.9', '4', '8.8', '2.8', '2.1', '1.3',
#        '7.3', '15.3', '11.3', '11.9', '10.7', '15.7', '6.1', '2.6', '9.9',
#        '11.6', '12.1', '4.2', '10.2', '6.3', '14.6', '16.1', '17.2',
#        '16.8', '18.4', '20.4', '22.3', '20.9', '20.3', '13.7', '13.2',
#        '19.9', '30.2', '5.9', '7.7', '9.7', '8.3', '0.7', '4.1', '1',
#        '3.1', '1.9', '10', '16.7', '1.2', '5.3', '6.7', '9.5', '12',
#        '6.4', '5.2', '3', '9.6', '4.7', 'fire', '14.1', '9.1', '13',
#        '17.3', '30', '25.4', '16.3', '9', '14.5', '13.5', '19.5', '12.6',
#        '12.7', '21.6', '18.8', '10.5', '5.5', '14.8', '24', '26.3',
#        '12.2', '18.1', '24.5', '26.9', '31.1', '30.3', '26.1', '16',
# ...

# %%
df[df['FWI']=='fire'].index
# Out:
# Int64Index([165], dtype='int64')

# %%
df.loc[165,'FWI'] = '0.4'

# %%
df['DC'] = df['DC'].str.replace(" ","")

# %%
#label encoding
df['Classes'] = df['Classes'].str.replace('notfire','0')
df['Classes'] = df['Classes'].str.replace('fire','1')

# %% [markdown]
# # Changing Datatypes

# %%
df['day'] = df['day'].astype(int)
df['month'] = df['month'].astype(int)
df['year'] = df['year'].astype(int)
df['Temperature'] = df['Temperature'].astype(int)
df['RH']    = df['RH'].astype(int)
df['Ws']    = df['Ws'].astype(int)
df['Rain']  = df['Rain'].astype(float)
df['FFMC']  = df['FFMC'].astype(float)
df['DMC']   = df['DMC'].astype(float)
df['DC']    = df['DC'].astype(float)
df['ISI']   = df['ISI'].astype(float)
df['BUI']   = df['BUI'].astype(float)
df['FWI']   = df['FWI'].astype(float)
df['Classes'] =df['Classes'].astype(float)
df['Region'] =df['Region'].astype(float)

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes        float64
# Region         float64
# dtype: object

# %%
df.shape
# Out:
# (244, 15)

# %%
df.isna().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %% [markdown]
# # Numerical & Categorical Feature

# %%
cat_col = [fea for fea in df.columns if df[fea].dtype == 'o']

# %%
for i in cat_col:
    print(df.groupby(i)['Region'].value_counts())

# %%
sns.countplot(data=df,x='Classes',hue='Region')
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='count'>

# %% [markdown]
# 1. sidi Bel-abbes has more occurance of fire

# %%
num_col = [fea for fea in df.columns if df[fea].dtype !='o']

# %%
df[num_col].nunique()
# Out:
# day             31
# month            4
# year             1
# Temperature     19
# RH              62
# Ws              18
# Rain            39
# FFMC           173
# DMC            166
# DC             198
# ISI            106
# BUI            174
# FWI            125
# Classes          2
# Region           2
# dtype: int64

# %%
len(num_col)
# Out:
# 15

# %% [markdown]
# # Segregating Discrete and continuos Feature

# %% [markdown]
# # Discrete

# %%
#we are assuming 32 as threshold were feature having less than 32 is discrete
dist_fea = [fea for fea in num_col if len(df[fea].unique())<32]
dist_fea
# Out:
# ['day', 'month', 'year', 'Temperature', 'Ws', 'Classes', 'Region']

# %%
for feature in dist_fea:
    sns.countplot(data=df,x=feature,hue='Classes')
    plt.show()

# %% [markdown]
# # continous

# %%
cont_fea = [fea for fea in num_col if fea not in dist_fea]
cont_fea
# Out:
# ['RH', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']

# %%
import scipy.stats as stats

# %%
for i in cont_fea:
    plt.figure(figsize=(15,6))
    plt.subplot(121)
    sns.histplot(data=df,x=i,kde=True,bins=30,color='green')
    plt.title("{}'s distribution".format(i),fontweight='bold')
    
    plt.subplot(122)
    stats.probplot(df[i],dist='norm',plot=plt)
    plt.title("{}'s Q-Q plot".format(i),fontweight='bold')

# %% [markdown]
# # Comparing Continous Numerical feature with region

# %%
plt.figure(figsize=(20,40))
for i in enumerate(cont_fea):
    plt.subplot(4,2,i[0]+1)
    sns.set(rc={'figure.figsize':(7,7)})
    sns.histplot(data=df,x=i[1],kde=True,bins=30,color='blue',hue='Region')
    plt.title("{} vs Region".format(i[1],fontweight='bold'))

# %%
plt.figure(figsize=(20,40))
for i in enumerate(cont_fea):
    plt.subplot(4,2,i[0]+1)
    sns.set(rc={'figure.figsize':(7,7)})
    sns.histplot(data=df,x=i[1],kde=True,bins=30,color='blue',hue='Classes')
    plt.title("{} Vs Classes".format(i[1],fontweight='bold'))

# %% [markdown]
# # Checking for Outliers

# %%
plt.figure(figsize=(20,40))
for i in enumerate(num_col):
    plt.subplot(8,2, i[0]+1)
    sns.set(rc={'figure.figsize':(7,7)})
    sns.boxplot(data=df,x=i[1],color='y')
    plt.title("{}".format(i[1]),fontweight="bold")

# %% [raw]
# observation:
# 1.Relative Humidity doesn't have outlier
# 2.Temperature and FFMC has outlier on it's lower side
# 3.wind speed has outlier on both of it's side
# 4.Rain,DMC,DC,ISI,BUI,FWI has outlier on it's lower boundary

# %% [markdown]
# # Correlation for each numerical feature

# %%
data = round(df[[feature for feature in num_col if feature not in['day','month','year','Region']]].corr(),2)
data
# Out:
#              Temperature    RH    Ws  Rain  FFMC   DMC    DC   ISI   BUI  \
# Temperature         1.00 -0.65 -0.28 -0.33  0.68  0.48  0.37  0.61  0.46
# RH                 -0.65  1.00  0.24  0.22 -0.65 -0.41 -0.22 -0.69 -0.35
# Ws                 -0.28  0.24  1.00  0.17 -0.16 -0.00  0.08  0.02  0.03
# Rain               -0.33  0.22  0.17  1.00 -0.54 -0.29 -0.30 -0.35 -0.30
# FFMC                0.68 -0.65 -0.16 -0.54  1.00  0.60  0.50  0.74  0.59
# DMC                 0.48 -0.41 -0.00 -0.29  0.60  1.00  0.88  0.67  0.98
# DC                  0.37 -0.22  0.08 -0.30  0.50  0.88  1.00  0.50  0.94
# ISI                 0.61 -0.69  0.02 -0.35  0.74  0.67  0.50  1.00  0.64
# BUI                 0.46 -0.35  0.03 -0.30  0.59  0.98  0.94  0.64  1.00
# FWI                 0.56 -0.57  0.03 -0.32  0.69  0.87  0.74  0.91  0.86
# Classes             0.52 -0.44 -0.07 -0.38  0.77  0.58  0.51  0.74  0.58
#
#               FWI  Classes
# Temperature  0.56     0.52
# RH          -0.57    -0.44
# ...

# %% [markdown]
# # Heatmap to visualise the feature

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(data=df, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Vs Target

# %%
sns.scatterplot(data=df,x='day',y='Temperature',hue='Classes')
# Out:
# <AxesSubplot:xlabel='day', ylabel='Temperature'>

# %% [markdown]
# # obersavtion:

# %% [markdown]
# Most cases of fire occur at Temperature more than 30 degree celcius

# %%
sns.scatterplot(data=df,x='month',y='Temperature',hue='Classes')
# Out:
# <AxesSubplot:xlabel='month', ylabel='Temperature'>

# %% [markdown]
# # Observation:

# %% [markdown]
# Most cases of fire occur in the month of July and August

# %%
sns.scatterplot(data=df,x='Region',y='Temperature',hue='Classes')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Temperature'>

# %% [markdown]
# # Observation:

# %% [markdown]
# 1. In Bejaia region, the no of cases of occurance of fire is less compared to no of cases of occurance of no fire.
# 2. In Sidi Bel-abbes region the no of cases of occurance of fire is more compared to no fire.
# 3. Also Overall no of cases of occurance of fire is more in Sidi Bel-abbes region as compared to Bejaia region.

# %%
for feature in [feature for feature in df.columns if feature not in ['Temperature']]:
    sns.set(rc={'figure.figsize':(8,8)})
    sns.regplot(x=df[feature],y=df['Temperature'])
    #plt.xlabel(feature)
    #plt.ylabel('Temperature')
    plt.title("{} vs Temperature".format[feature])
    plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
#       3 sns.regplot(x=df[feature],y=df['Temperature'])
#       4 #plt.xlabel(feature)
#       5 #plt.ylabel('Temperature')
# ----> 6 plt.title("{} vs Temperature".format[feature])
#       7 plt.show()
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
